# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
cv2.imread('/content/drive/MyDrive/cats (2).jpg')
# Out:
# array([[[195, 136,  87],
#         [195, 136,  87],
#         [195, 136,  87],
#         ...,
#         [175, 102,  58],
#         [177, 104,  60],
#         [176, 106,  59]],
#
#        [[196, 137,  88],
#         [197, 138,  89],
#         [198, 139,  90],
#         ...,
#         [175, 101,  59],
#         [177, 104,  60],
#         [177, 106,  62]],
#
#        [[196, 138,  89],
#         [198, 140,  91],
#         [200, 142,  93],
#         ...,
#         [175, 100,  61],
#         [177, 103,  61],
#         [177, 105,  63]],
#
#        ...,
#
#        [[209, 156, 113],
#         [194, 143, 100],
#         [189, 138,  95],
#         ...,
#         [131, 128, 144],
#         [120, 117, 133],
#         [103,  98, 113]],
#
#        [[212, 161, 118],
#         [209, 158, 115],
#         [201, 150, 107],
#         ...,
#         [142, 141, 157],
#         [124, 123, 139],
#         [107, 104, 119]],
#
#        [[210, 159, 116],
#         [216, 165, 122],
#         [214, 165, 121],
# ...

# %%
img=cv2.imread('/content/drive/MyDrive/cats (2).jpg')

# %%
cv2.resize(img,(800,500))
# Out:
# array([[[195, 136,  87],
#         [195, 136,  87],
#         [195, 136,  87],
#         ...,
#         [176, 103,  60],
#         [176, 105,  59],
#         [176, 106,  59]],
#
#        [[195, 136,  87],
#         [195, 136,  87],
#         [196, 137,  88],
#         ...,
#         [177, 104,  60],
#         [176, 105,  60],
#         [176, 106,  60]],
#
#        [[196, 137,  88],
#         [196, 137,  88],
#         [197, 138,  89],
#         ...,
#         [176, 103,  60],
#         [177, 105,  61],
#         [177, 106,  62]],
#
#        ...,
#
#        [[212, 161, 118],
#         [210, 159, 116],
#         [208, 157, 114],
#         ...,
#         [127, 126, 142],
#         [115, 113, 129],
#         [107, 104, 119]],
#
#        [[211, 160, 117],
#         [212, 161, 118],
#         [212, 161, 119],
#         ...,
#         [132, 131, 147],
#         [122, 119, 135],
#         [114, 110, 126]],
#
#        [[210, 159, 116],
#         [213, 162, 119],
#         [216, 165, 122],
# ...

# %%
cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
# Out:
# array([[[210, 159, 116],
#         [212, 161, 118],
#         [209, 156, 113],
#         ...,
#         [196, 138,  89],
#         [196, 137,  88],
#         [195, 136,  87]],
#
#        [[216, 165, 122],
#         [209, 158, 115],
#         [194, 143, 100],
#         ...,
#         [198, 140,  91],
#         [197, 138,  89],
#         [195, 136,  87]],
#
#        [[214, 165, 121],
#         [201, 150, 107],
#         [189, 138,  95],
#         ...,
#         [200, 142,  93],
#         [198, 139,  90],
#         [195, 136,  87]],
#
#        ...,
#
#        [[148, 147, 163],
#         [142, 141, 157],
#         [131, 128, 144],
#         ...,
#         [175, 100,  61],
#         [175, 101,  59],
#         [175, 102,  58]],
#
#        [[133, 132, 148],
#         [124, 123, 139],
#         [120, 117, 133],
#         ...,
#         [177, 103,  61],
#         [177, 104,  60],
#         [177, 104,  60]],
#
#        [[118, 115, 130],
#         [107, 104, 119],
#         [103,  98, 113],
# ...

# %%
cv2.flip(img,0)
# Out:
# array([[[210, 159, 116],
#         [216, 165, 122],
#         [214, 165, 121],
#         ...,
#         [148, 147, 163],
#         [133, 132, 148],
#         [118, 115, 130]],
#
#        [[212, 161, 118],
#         [209, 158, 115],
#         [201, 150, 107],
#         ...,
#         [142, 141, 157],
#         [124, 123, 139],
#         [107, 104, 119]],
#
#        [[209, 156, 113],
#         [194, 143, 100],
#         [189, 138,  95],
#         ...,
#         [131, 128, 144],
#         [120, 117, 133],
#         [103,  98, 113]],
#
#        ...,
#
#        [[196, 138,  89],
#         [198, 140,  91],
#         [200, 142,  93],
#         ...,
#         [175, 100,  61],
#         [177, 103,  61],
#         [177, 105,  63]],
#
#        [[196, 137,  88],
#         [197, 138,  89],
#         [198, 139,  90],
#         ...,
#         [175, 101,  59],
#         [177, 104,  60],
#         [177, 106,  62]],
#
#        [[195, 136,  87],
#         [195, 136,  87],
#         [195, 136,  87],
# ...

# %%
cv2.threshold(img,127,255,cv2.THRESH_BINARY)
# Out:
# (127.0,
#  array([[[255, 255,   0],
#          [255, 255,   0],
#          [255, 255,   0],
#          ...,
#          [255,   0,   0],
#          [255,   0,   0],
#          [255,   0,   0]],
#
#         [[255, 255,   0],
#          [255, 255,   0],
#          [255, 255,   0],
#          ...,
#          [255,   0,   0],
#          [255,   0,   0],
#          [255,   0,   0]],
#
#         [[255, 255,   0],
#          [255, 255,   0],
#          [255, 255,   0],
#          ...,
#          [255,   0,   0],
#          [255,   0,   0],
#          [255,   0,   0]],
#
#         ...,
#
#         [[255, 255,   0],
#          [255, 255,   0],
#          [255, 255,   0],
#          ...,
#          [255, 255, 255],
#          [  0,   0, 255],
#          [  0,   0,   0]],
#
#         [[255, 255,   0],
#          [255, 255,   0],
#          [255, 255,   0],
#          ...,
#          [255, 255, 255],
#          [  0,   0, 255],
#          [  0,   0,   0]],
#
#         [[255, 255,   0],
# ...

# %%
from cv2.gapi import gaussianBlur
blur=cv2.blur(img,(5,5))
gaussianBlur=cv2.GaussianBlur(img,(5,5),0)
medianBlur=cv2.medianBlur(img,5)
bilateralFilter=cv2.bilateralFilter(img,9,75,75)
cv2_imshow(bilateralFilter)
# Out:
# <PIL.Image.Image image mode=RGB size=535x298>

# %%
cv2.ShapeTransformer(img,cv2.COLOR_BGR2GRAY)
cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# Out:
# array([[128, 128, 128, ...,  97,  99, 100],
#        [129, 130, 131, ...,  97,  99, 101],
#        [130, 132, 134, ...,  97,  99, 101],
#        ...,
#        [149, 136, 131, ..., 133, 122, 103],
#        [154, 151, 143, ..., 146, 128, 109],
#        [152, 158, 157, ..., 152, 137, 120]], dtype=uint8)

# %%
cv2.COLOR_HSV2BGR
# Out:
# 54

# %%
cv2.medianBlur(img,5)
# Out:
# array([[[195, 136,  87],
#         [196, 137,  88],
#         [196, 137,  88],
#         ...,
#         [175, 102,  59],
#         [176, 104,  59],
#         [176, 105,  59]],
#
#        [[196, 137,  88],
#         [196, 138,  89],
#         [197, 138,  89],
#         ...,
#         [175, 101,  59],
#         [176, 104,  60],
#         [177, 105,  61]],
#
#        [[196, 139,  90],
#         [197, 139,  90],
#         [198, 140,  91],
#         ...,
#         [175, 100,  60],
#         [176, 102,  61],
#         [177, 104,  62]],
#
#        ...,
#
#        [[209, 156, 113],
#         [203, 153, 107],
#         [201, 153, 107],
#         ...,
#         [136, 134, 153],
#         [126, 123, 139],
#         [119, 116, 132]],
#
#        [[210, 159, 116],
#         [209, 159, 116],
#         [209, 159, 116],
#         ...,
#         [136, 134, 153],
#         [126, 123, 139],
#         [118, 115, 130]],
#
#        [[210, 159, 116],
#         [210, 159, 116],
#         [210, 161, 117],
# ...

# %%
cv2.bilateralFilter(img,9,75,75)
# Out:
# array([[[198, 140,  91],
#         [198, 140,  91],
#         [199, 140,  91],
#         ...,
#         [173,  99,  59],
#         [175, 101,  60],
#         [175, 101,  60]],
#
#        [[198, 140,  91],
#         [198, 140,  91],
#         [199, 141,  92],
#         ...,
#         [173,  99,  59],
#         [174, 100,  60],
#         [175, 101,  60]],
#
#        [[198, 140,  91],
#         [198, 141,  92],
#         [199, 141,  92],
#         ...,
#         [173,  98,  59],
#         [174,  99,  60],
#         [175, 100,  61]],
#
#        ...,
#
#        [[203, 153, 109],
#         [200, 150, 106],
#         [197, 148, 104],
#         ...,
#         [136, 135, 152],
#         [131, 130, 146],
#         [125, 123, 139]],
#
#        [[203, 153, 109],
#         [203, 153, 109],
#         [201, 151, 107],
#         ...,
#         [140, 139, 156],
#         [131, 129, 146],
#         [125, 123, 139]],
#
#        [[202, 152, 108],
#         [204, 154, 110],
#         [203, 154, 110],
# ...

# %%
cv2.stackBlur(img,(5,5))
# Out:
# array([[[195, 136,  87],
#         [196, 137,  88],
#         [196, 137,  88],
#         ...,
#         [174, 100,  57],
#         [175, 103,  58],
#         [176, 104,  59]],
#
#        [[196, 137,  88],
#         [197, 138,  89],
#         [197, 139,  90],
#         ...,
#         [174, 100,  58],
#         [175, 102,  59],
#         [176, 104,  60]],
#
#        [[196, 138,  89],
#         [197, 139,  90],
#         [199, 140,  91],
#         ...,
#         [173,  99,  59],
#         [175, 101,  61],
#         [176, 103,  62]],
#
#        ...,
#
#        [[197, 146, 102],
#         [198, 147, 103],
#         [199, 149, 105],
#         ...,
#         [135, 133, 149],
#         [124, 122, 138],
#         [115, 111, 127]],
#
#        [[205, 154, 110],
#         [204, 153, 110],
#         [204, 154, 110],
#         ...,
#         [138, 136, 153],
#         [126, 124, 140],
#         [116, 113, 128]],
#
#        [[210, 159, 116],
#         [209, 159, 116],
#         [208, 159, 115],
# ...

# %%
cv2.detailEnhance(img,sigma_s=10,sigma_r=0.15)
# Out:
# array([[[187, 128,  78],
#         [187, 129,  78],
#         [187, 129,  79],
#         ...,
#         [192, 117,  77],
#         [198, 122,  83],
#         [199, 126,  84]],
#
#        [[189, 131,  81],
#         [192, 134,  84],
#         [196, 137,  88],
#         ...,
#         [191, 115,  77],
#         [198, 123,  83],
#         [201, 128,  89]],
#
#        [[191, 133,  83],
#         [197, 139,  90],
#         [203, 145,  96],
#         ...,
#         [191, 114,  78],
#         [197, 121,  83],
#         [201, 126,  89]],
#
#        ...,
#
#        [[218, 164, 122],
#         [173, 123,  79],
#         [157, 108,  62],
#         ...,
#         [ 87,  84,  99],
#         [ 62,  59,  73],
#         [ 20,  16,  28]],
#
#        [[230, 179, 136],
#         [219, 168, 125],
#         [193, 143,  99],
#         ...,
#         [125, 124, 140],
#         [ 79,  78,  93],
#         [ 35,  33,  45]],
#
#        [[224, 172, 130],
#         [241, 189, 146],
#         [237, 187, 143],
# ...
